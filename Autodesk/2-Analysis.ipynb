# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime

# load the data
data_dir = os.getcwd() + '\\data\\'

data = pd.read_csv(data_dir + '1.csv', index_col='ms')

# %%
def plot_chart(data, column_name, label, view_range = None):
 
    cols = ['time', column_name, 'schedule_tav']
    
    d = data[cols]
    d = d.set_index(['time'])
    
    plt.figure(figsize = (15,4))
    
    if view_range is None:
        p1 = d[column_name].plot()
        p2 = d['schedule_tav'].plot(secondary_y = True)
    else:
        p1 = d[column_name][view_range].plot()
        p2 = d['schedule_tav'][view_range].plot(secondary_y = True)
        
    p1.set_ylabel(label)
    #p1.set_xticks([])

    plt.gcf().autofmt_xdate()
    
    p2.margins(0, 0.1)
    p1.set_xlabel('Time')
    plt.show()

# %% [markdown]
# ### CO2

# %%
rang = np.arange(9300, 10000)
plot_chart(data, 'co2_1_tav', 'CO2 (1)')
plot_chart(data, 'co2_1_tav', 'CO2 (1)', rang)

# %%
rang = np.arange(9300, 10000)
plot_chart(data, 'co2_2_tav', 'CO2 (2)')
plot_chart(data, 'co2_2_tav', 'CO2 (2)', rang)

# %% [markdown]
# ### Light

# %%
plot_chart(data, 'light_1_tav', 'Light (1)')
plot_chart(data, 'light_1_tav', 'Light (1)', rang)

# %% [markdown]
# ### Motion

# %%
plot_chart(data, 'motion_tav', 'Motion')
plot_chart(data, 'motion_tav', 'Motion', rang)

# %% [markdown]
# ### Power

# %%
plot_chart(data, 'power_1_tav', 'Power (1)')
plot_chart(data, 'power_1_tav', 'Power (1)', rang)

# %%
plot_chart(data, 'power_2_tav', 'Power (2)')
plot_chart(data, 'power_2_tav', 'Power (2)', rang)

# %% [markdown]
# ### Sound

# %%
plot_chart(data, 'sound_tav', 'Sound')
plot_chart(data, 'sound_tav', 'Sound', rang)

# %%
data.shape
# Out:
# (16876, 28)
